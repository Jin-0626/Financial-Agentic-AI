# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from agent import graph\n",
#     "from langchain_core.messages import HumanMessage\n",
#     "\n",
#     "inputs = {\n",
#     "    \"messages\": [\n",
#     "        HumanMessage(content=\"Generate an equity research report on Maybank (MBBM.KL). Evaluate recent financial performance, risks, and target price considerations.\")\n",
#     "    ]\n",
#     "}\n",
#     "\n",
#     "for chunk in graph.stream(inputs, stream_mode=\"values\"):\n",
#     "    message = chunk[\"messages\"][-1]\n",
#     "    message.pretty_print()"
#    ]
#   }
#  ],
#  "metadata": {
#   "language_info": { "name": "python" }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
